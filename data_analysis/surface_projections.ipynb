# %%
import SUITPy.flatmap as flatmap
import matplotlib.pyplot as plt
import smarts_cerebellum.globals as gl
import os

# %%
space = 'MNISym'
stats = 'nanmean' # for discrete data; module (by-default) assumes continuous functional data

# in previous, we did vol_to_surf without stats = 'mode'

mean_path = os.path.join(gl.baseDir, 'Regression', 'mean_images')
median_path = os.path.join(gl.baseDir, 'Regression', 'median_images')

# %% [markdown]
# **rerunning this, but with CUP_1001 (control subject) excluded for outlier from the mean, median images for GM ONLY**

# %% [markdown]
# ## Surface projections of GM

# %%
datatype = 'GM'
group = 'patients'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} mean slope')
# Out:
# Text(0.5, 1.0, 'patients GM mean slope')

# %%
group = 'controls'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean_exclude.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} mean slope exclude')
# Out:
# Text(0.5, 1.0, 'controls GM mean slope exclude')

# %% [markdown]
# It is possible that the controls' image looks like this because of the outlier we identified in analysis (CUP_1001).
#
# Should perform that analysis and determine if there are outliers we should consider for our surface projections.

# %%
group = 'patients'

filename = f'{group}_{space}_{datatype}_coreg_slope_median.nii'
funcdata = flatmap.vol_to_surf(median_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} median slope')
# Out:
# Text(0.5, 1.0, 'patients GM median slope')

# %%
group = 'controls'

filename = f'{group}_{space}_{datatype}_coreg_slope_median_exclude.nii'
funcdata = flatmap.vol_to_surf(median_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} median slope exclude')
# Out:
# Text(0.5, 1.0, 'controls GM median slope exclude')

# %% [markdown]
# ## Surface projections of WM

# %%
datatype = 'WM'

# %%
group = 'patients'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} mean slope')
# Out:
# Text(0.5, 1.0, 'patients WM mean slope')

# %%
group = 'controls'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} mean slope')
# Out:
# Text(0.5, 1.0, 'controls WM mean slope')

# %%
group = 'patients'

filename = f'{group}_{space}_{datatype}_coreg_slope_median.nii'
funcdata = flatmap.vol_to_surf(median_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} median slope')
# Out:
# Text(0.5, 1.0, 'patients WM median slope')

# %%
group = 'controls'

filename = f'{group}_{space}_{datatype}_coreg_slope_median.nii'
funcdata = flatmap.vol_to_surf(median_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True, cscale=(-.005, .005))
plt.title(f'{group} {datatype} median slope')
# Out:
# Text(0.5, 1.0, 'controls WM median slope')

# %%
group = 'patients'
datatype = 'T1'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True,)
plt.title(f'{group} {datatype} mean slope')
# Out:
# Text(0.5, 1.0, 'patients T1 mean slope')

# %%
group = 'controls'
datatype = 'T1'

filename = f'{group}_{space}_{datatype}_coreg_slope_mean.nii'
funcdata = flatmap.vol_to_surf(mean_path + '/'+ filename,space=space, stats = stats)
flatmap.plot(data=funcdata, cmap='bwr', new_figure=True, colorbar=True,)
plt.title(f'{group} {datatype} mean slope')
# Out:
# Text(0.5, 1.0, 'controls T1 mean slope')
