# %% [markdown]
# # editor for week_path_builder function
#
# This function is to build a path for week_path. This notebook is its editor.

# %%
# add project root
import sys
sys.path.append('/home/UWO/mporwal2/Documents/GitHub/smarts_cerebellum/')

# %%
# Imports

import numpy as np

from pathlib import Path
import os

from helper_functions import parent_lookup
from helper_functions import week_path_builder

# %%
base_dir = '/cifs/diedrichsen/data/smarts_cerebellum'

# %%
parent_lookup.parent_lookup?
# Out:
# Signature: parent_lookup.parent_lookup(file_path, subj_id)
# Docstring:
# Looks for subject parent directory of a reference file. Also tracks how many *n* parents there are.
#
# e.g. If you have a reference file and want to access all other files in its parent (or grandparent, n^th-level parent) directory.
#
# Inputs:
#     file_path (str or Posix path)
#     subj_id: str
#
# Outputs:
#     parent (PosixPath): subj_id parent folder
#     level (int): levels from reference image to parent folder
# File:      ~/Documents/GitHub/smarts_cerebellum/helper_functions/parent_lookup.py
# Type:      function

# %%
week_path_builder.week_path_builder?
# Out:
# Signature:
# week_path_builder.week_path_builder(
#     reference_image,
#     subj_id,
#     subdir,
#     suffix,
#     tissue,
#     week_folder,
# )
# Docstring:
# Inputs:
#     reference_image: in avg_vol
#     subj_id: in avg_vol
#
#     subdir: in avg_vol (NEED TO CHANGE NAME HERE)
#
#     suffix: in avg_vol; DOCUMENTATION: NEED TO INCLUDE .NII OR .NII.GZ
#     tissue: in avg_vol
#
#     week_folder: need to add to avg_vol; boolean; whether files are stored within a weeks folder or just flat (then False)
#
# Output:
#     week_path (str): path to file for that week
#     weeks_available (list): weeks with available files (as W0, ..., etc.)
#         This can be used in response_matrix() for avg_vol function
#
# ______________
#
# This function follows the naming convention:
#     <tissue_segmentation><subj_id>_<week>_<suffix>
#
#         - tissue_segmentation: c1, ..., c5 (if segmentation file from SPM); if tissue = None, then that space is empty
# ...

# %% [markdown]
# **building file path**
#
# So the path will look like:
# base_path = (trial_path/subdir if subdir not None else trial_path)
#
#
# week_folder = (True/False, boolean)
#
# suffix: (str)
#
# And look for tissue segmentation, if requested:
#
# prefix = '' # prefix is nothing by default; only has something if there is a tissue segmentation file to be found
#
# if not tissue=None:
#     prefix = tissue_dict[tissue] + '_'
#
# Then: if week_folder not False, for week in weeks, week_path = f'{base_path}/{week}/{prefix}{subj_id}_{week}_{suffix}.nii.gz
#
# else week_path = f'{base_path}/{prefix}{subj_id}__{week}_{suffix}.nii.gz

# %%
# def week_path_builder(reference_image, subj_id, subdir, suffix, tissue, week_folder):
#     """
#     Inputs:
#         reference_image: in avg_vol
#         subj_id: in avg_vol

#         subdir: in avg_vol (NEED TO CHANGE NAME HERE)
        
#         suffix: in avg_vol; DOCUMENTATION: NEED TO INCLUDE .NII OR .NII.GZ
#         tissue: in avg_vol

#         week_folder: need to add to avg_vol; boolean; whether files are stored within a weeks folder or just flat (then False)

#     Output:
#         week_path (str): path to file for that week
#         weeks_available (list): weeks with available files (as W0, ..., etc.)
#             This can be used in response_matrix() for avg_vol function

#     ______________

#     This function follows the naming convention:
#         <tissue_segmentation><subj_id>_<week>_<suffix> 
            
#             - tissue_segmentation: c1, ..., c5 (if segmentation file from SPM); if tissue = None, then that space is empty
#             - suffix: see file_naming_conventions in README; end in .nii or .nii.gz
#     """

#     parent_path, level = parent_lookup.parent_lookup(file_path = reference_image, subj_id = subj_id)

#     base_path = (Path(parent_path/subdir) if not subdir == None else parent_path)

#     prefix = '' # empty string by default

#     tissue_dict = {
#     'gm': 'c1',
#     'wm': 'c2',
#     'csf': 'c3'
#     }

#     if not tissue == None:
#         prefix = tissue_dict[tissue]
#         print(tissue)

#         # this part is the weeks loop___________________

#     weeks = np.array([0,4,12,24,52])

#     week_paths = []
#     weeks_available = []

#     for week in weeks:
#         if week_folder == True:
#             potential_path = f'{base_path}/W{week}/{prefix}{subj_id}_W{week}_{suffix}'
#         else:
#             potential_path = f'{base_path}/{prefix}{subj_id}_W{week}_{suffix}'

#         # check if file exists
#         if not os.path.exists(potential_path):
#             print("skipping", subj_id, "W", week)
#             continue

#         # only return the path if it exists
#         week_paths.append(potential_path)
#         weeks_available.append('W' + week.astype(str))

#     return week_paths, weeks_available

# %% [markdown]
# **function test cases**
#
# 1. base_path: subdir = None and subdir = '...'
#
# 2. prefix: tissue = None and tissue = '...'
#
# 3. week_folder: False, True

# %%
# test case (1): subdir = None

subj_id = 'CU_2538'
refT1 = 'W0'
#ref_img = f'{base_dir}/MNISym_GM/{subj_id}/{subj_id}_{refT1}_reslice.nii.gz'
ref_img = f'{base_dir}/anatomicals/{subj_id}/{refT1}/c2{subj_id}_{refT1}_T1.nii'

this_path, all_weeks = week_path_builder.week_path_builder(reference_image = ref_img, 
                              subj_id = subj_id,
                              subdir = None,
                              suffix = 'T1.nii',
                              tissue = None,
                              week_folder = True
                              )
# Out:
# skipping CU_2538 W 12
# skipping CU_2538 W 24
# skipping CU_2538 W 52

# %%
this_path
# Out:
# ['/cifs/diedrichsen/data/smarts_cerebellum/anatomicals/CU_2538/W0/CU_2538_W0_T1.nii',
#  '/cifs/diedrichsen/data/smarts_cerebellum/anatomicals/CU_2538/W4/CU_2538_W4_T1.nii']

# %%
all_weeks
# Out:
# ['W0', 'W4']

# %%
# test case (2): subdir = cerebellar_alignment, using tissue

subj_id = 'CU_2538'
refT1 = 'W0'
#ref_img = f'{base_dir}/MNISym_GM/{subj_id}/{subj_id}_{refT1}_reslice.nii.gz'
ref_img = f'{base_dir}/anatomicals/{subj_id}/cerebellar_alignment/{refT1}/c2{subj_id}_{refT1}_T1.nii'

this_path = week_path_builder.week_path_builder(reference_image = ref_img, 
                              subj_id = subj_id,
                              subdir = 'cerebellar_alignment',
                              suffix = 'T1.nii',
                              tissue = 'wm',
                              week_folder = True
                              )
# Out:
# wm
# skipping CU_2538 W 12
# skipping CU_2538 W 24
# skipping CU_2538 W 52

# %%
this_path
# Out:
# (['/cifs/diedrichsen/data/smarts_cerebellum/anatomicals/CU_2538/cerebellar_alignment/W0/c2CU_2538_W0_T1.nii',
#   '/cifs/diedrichsen/data/smarts_cerebellum/anatomicals/CU_2538/cerebellar_alignment/W4/c2CU_2538_W4_T1.nii'],
#  ['W0', 'W4'])

# %%
# test case (2): tissue = None

subj_id = 'CU_2538'
refT1 = 'W0'
#ref_img = f'{base_dir}/MNISym_GM/{subj_id}/{subj_id}_{refT1}_reslice.nii.gz'
ref_img = f'{base_dir}/anatomicals/{subj_id}/{refT1}/{subj_id}_{refT1}_T1.nii'

this_path, all_weeks = week_path_builder.week_path_builder(reference_image = ref_img, 
                              subj_id = subj_id,
                              subdir = None,
                              suffix = 'T1.nii',
                              tissue = None,
                              week_folder = True
                              )
# Out:
# skipping CU_2538 W 12
# skipping CU_2538 W 24
# skipping CU_2538 W 52

# %%
# test case (3): week_folder = False

subj_id = 'CU_2538'
refT1 = 'W0'
ref_img = f'{base_dir}/MNISym_GM/{subj_id}/{subj_id}_{refT1}_MNISym_GM_reslice.nii.gz'
#ref_img = f'{base_dir}/anatomicals/{subj_id}/{refT1}/{subj_id}_{refT1}_T1.nii'

this_path, all_weeks = week_path_builder.week_path_builder(reference_image = ref_img, 
                              subj_id = subj_id,
                              subdir = None,
                              suffix = 'MNISym_GM_reslice.nii.gz',
                              tissue = None,
                              week_folder = False
                              )
# Out:
# skipping CU_2538 W 12
# skipping CU_2538 W 24
# skipping CU_2538 W 52

# %%
this_path, all_weeks
# Out:
# (['/cifs/diedrichsen/data/smarts_cerebellum/MNISym_GM/CU_2538/CU_2538_W0_MNISym_GM_reslice.nii.gz',
#   '/cifs/diedrichsen/data/smarts_cerebellum/MNISym_GM/CU_2538/CU_2538_W4_MNISym_GM_reslice.nii.gz'],
#  ['W0', 'W4'])

# %%
p_weeks = all_weeks
p_paths = this_path

# %%
for week_path, week_num in zip(p_paths, p_weeks):
    print(week_path, "and", week_num, "\n")
# Out:
# /cifs/diedrichsen/data/smarts_cerebellum/MNISym_GM/CU_2538/CU_2538_W0_MNISym_GM_reslice.nii.gz and W0
#
# /cifs/diedrichsen/data/smarts_cerebellum/MNISym_GM/CU_2538/CU_2538_W4_MNISym_GM_reslice.nii.gz and W4
