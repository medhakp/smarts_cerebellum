# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![wm_slope_slice_2.png](attachment:wm_slope_slice_2.png)

# %% [markdown]
# ![wm_slope_slice_3.png](attachment:wm_slope_slice_3.png)
