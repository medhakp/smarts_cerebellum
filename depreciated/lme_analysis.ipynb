# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import smarts_cerebellum.globals as gl

# %%
df = pd.read_csv(f'{gl.baseDir}/lme/lme_summarized_df.tsv', sep = '\t')
df_beta = df[df.param=='beta']


# if patients in model, controls just mean in MNISym (w/out model)
#df = pd.read_csv(f'{gl.baseDir}/lme/pc_lme_summarized_df.tsv', sep = '\t')
# df_p_beta = df[(df.group == 'patients') & (df.param == 'beta')]
# df_beta = pd.concat([df_p_beta, df[df.group == 'controls']], axis = 0, ignore_index = True)

rois = ['Left_VI', 'Left_V', 'Left_I_IV', 'Right_I_IV',  'Right_V',  'Right_VI', ]#'Left_Dentate', 'Right_Dentate', 'Left_Fastigial', 'Right_Fastigial', 'Left_Interposed', 'Right_Interposed',]

df_rois_CSF = df_beta[df_beta.regionname.isin(rois) & (df_beta.segment == 'CSF')]
df_rois_GM = df_beta[df_beta.regionname.isin(rois) & (df_beta.segment == 'GM')]
df_rois_WM = df_beta[df_beta.regionname.isin(rois) & (df_beta.segment == 'WM')]
df_rois_T1 = df_beta[df_beta.regionname.isin(rois) & (df_beta.segment == 'T1')]

# %%
weeks = df_rois_GM.Week.unique()
reds = sns.color_palette("Reds", n_colors=5)
blues = sns.color_palette("Blues", n_colors=5)

fig, ax = plt.subplots(figsize=(8,3))

sns.pointplot(data = df_rois_GM[df_rois_GM.group=='patients'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = reds, alpha = 0.7, dodge=True)
sns.pointplot(data = df_rois_GM[df_rois_GM.group=='controls'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = blues, alpha = 0.7, dodge=True)
#ax.set_ylim(0,1)
ax.set_title('mean GM in regions')
ax.legend(bbox_to_anchor=(1, .5), loc='center left', frameon=False)
sns.despine(trim = True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

sns.pointplot(data = df_rois_WM[df_rois_WM.group=='patients'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = reds, alpha = 0.7, dodge=True)
sns.pointplot(data = df_rois_WM[df_rois_WM.group=='controls'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = blues, alpha = 0.7, dodge=True)
#ax.set_ylim(0,1)
ax.set_title('mean WM in regions')
ax.legend(bbox_to_anchor=(1, .5), loc='center left', frameon=False)
sns.despine(trim = True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

sns.pointplot(data = df_rois_CSF[df_rois_CSF.group=='patients'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = reds, alpha = 0.7, dodge=True)
sns.pointplot(data = df_rois_CSF[df_rois_CSF.group=='controls'], x = 'regionname', y = 'mean', hue = 'Week', order=rois, palette = blues, alpha = 0.7, dodge=True)
#ax.set_ylim(0,1)
ax.set_title('mean CSF in regions')
ax.legend(bbox_to_anchor=(1, .5), loc='center left', frameon=False)
sns.despine(trim = True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

sns.pointplot(data = df_rois_T1[df_rois_T1.group=='patients'], x = 'regionname', y = 'mean', hue = 'Week', palette = reds, order=rois, alpha = 0.7, dodge=True)
#sns.pointplot(data = df_rois_T1[df_rois_T1.group=='controls'], x = 'regionname', y = 'mean', hue = 'Week', palette = blues, order=rois, alpha = 0.7, dodge=True)
#ax.set_ylim(0,1)
ax.set_title('mean T1 in regions')
ax.legend(bbox_to_anchor=(1, .5), loc='center left', frameon=False)
sns.despine(trim = True)
plt.show()
